# %%
x = None
print(x)
# Out:
# None

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
result = None
if result is None:
  print("No result yet")
else:
  print("Result is ready")
# Out:
# No result yet

# %%
result = None
if result is not None:
  print("Result is ready")
else:
  print("No result yet")
# Out:
# No result yet

# %%
print(bool(None))
# Out:
# False

# %%
def myfunc():
  x = 5

x = myfunc()
print(x)
# Out:
# None
